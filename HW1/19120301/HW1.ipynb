# %% [markdown]
# Họ tên: Võ Thành Nam
#
# MSSV: 19120301

# %% [markdown]
# # HW1: Giới thiệu CUDA

# %% [markdown]
# Với các GPU tương đối mới thì để biên dịch chỉ cần dùng câu lệnh: \
# `nvcc tên-file.cu -o tên-file-chạy`
#
# Nhưng trên Colab mình thường lấy được GPU khá cũ là Tesla K80 với compute capability (phiên bản phần cứng) là 3.7; để biên dịch đúng với GPU khá cũ này thì bạn cần dùng câu lệnh: \
# `nvcc -arch=sm_37 tên-file.cu -o tên-file-chạy` \
# Trong đó, 37 chính là compute capability của GPU Tesla K80.
#
# Để phòng trường hợp khi làm bài bạn lấy được GPU có compute capability x.x nhưng khi chấm bài Thầy lại lấy được GPU có compute capability khác x.x, dưới đây mình sẽ có đoạn code Python để tự động lấy 2 con số ứng với compute capability của GPU và lưu vào 2 biến `major` và `minor`:

# %%
from numba import cuda
major, minor = cuda.get_current_device().compute_capability
print(f'GPU compute capability: {major}.{minor}')
# Out:
# GPU compute capability: 7.5

# %% [markdown]
# Một khi đã chạy đoạn code Python ở trên, để biên dịch thì bạn sẽ dùng câu lệnh: \
# `nvcc -arch=sm_{major}{minor} tên-file.cu -o tên-file-chạy`

# %% [markdown]
# Dưới đây, khi làm bài thì bạn có thể tùy ý thêm/xóa cell. Đừng xóa mấy cell có chữ của Thầy là được.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# You should change this
# %cd /content/drive/MyDrive/ParallelProgramming
# Out:
# /content/drive/MyDrive/ParallelProgramming

# %% [markdown]
# ## Câu 1

# %%
# !nvcc -arch=sm_{major}{minor} HW1_P1.cu -o p1out
# !./p1out in.pnm out1.pnm 16 16
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 3.414016 ms
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 0.926816 ms
#
# Error between device result and host result: 0.002674

# %%
# !./p1out in.pnm out1.pnm 32 32
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 2.530080 ms
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 0.891648 ms
#
# Error between device result and host result: 0.002674

# %%
# !./p1out in.pnm out1.pnm 64 64
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 3.104448 ms
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 6.250368 ms
#
# Error between device result and host result: 119.969627

# %% [markdown]
# ## Câu 2

# %%
# !nvcc -arch=sm_{major}{minor} HW1_P2.cu -o p2out
# !./p2out in.pnm out2.pnm out2_target.pnm 16 16
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 489.250519 ms
# Error: 0.000000
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 4.997152 ms
# Error: 0.000703

# %%
# !./p2out in.pnm out2.pnm out2_target.pnm 32 32
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 593.321777 ms
# Error: 0.000000
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 5.133984 ms
# Error: 0.000703

# %%
# !./p2out in.pnm out2.pnm out2_target.pnm 64 64
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 295.068787 ms
# Error: 0.000000
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 2.860128 ms
# Error: 124.033791
